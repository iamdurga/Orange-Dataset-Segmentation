# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
img = cv2.imread("/content/drive/MyDrive/Orange Healthy And Infected Image Segmentation/orange2.jpg")

# %%
plt.imshow(img)

# %% [markdown]
# ## Converting to RGB ColorSpace

# %%
img_fix = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_fix)

# %% [markdown]
# ## Converting to HSV

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.imshow(img_hsv)

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## Lets detect the orange from image

# %%
import matplotlib.pyplot as plt

# Define the coordinates or indices of the region you want to extract
x1, x2 = 300, 1900  # Adjusted x2 value to ensure a non-zero width
y1, y2 = 400,1700

# Extract the specified part of the image using array slicing
only_orange = img_fix[y1:y2, x1:x2]

# Display the specified part of the image
plt.imshow(only_orange)
plt.show()
