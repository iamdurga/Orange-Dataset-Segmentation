# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
pic = Image.open("/content/drive/MyDrive/Orange Healthy And Infected Image Segmentation/orange1.jpg")

# %%
pic
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# ## Let's change the image into numpy array

# %%
import numpy as np
pic_arr = np.asarray(pic)
pic_arr.shape
# Out:
# (4160, 1872, 3)

# %%
plt.imshow(pic_arr)

# %% [markdown]
# ## Let's Separate the color from image

# %%
pic_red = pic_arr.copy()

# %%
pic_red[:,:,1] = 0 # Zeroput the contribution from green
pic_red[:,:,2] = 0 # Zeroput the contribution from blue

# %%
plt.imshow(pic_red)
